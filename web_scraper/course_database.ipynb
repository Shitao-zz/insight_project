# %%
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
import psycopg2
import pandas as pd

# %%
dbname = 'courses_db'
username = 'swang'
pswd = '1118'
engine = create_engine('postgresql://%s:%s@localhost/%s'%(username,pswd,dbname))
if not database_exists(engine.url):
    create_database(engine.url)
print(database_exists(engine.url))
# Out:
# True

# %%
course_data = pd.DataFrame.from_csv('udemy_courses_cleaned.csv')
course_data.to_sql('course_data_table', engine, if_exists='replace')

# %%
# connect:
con = None
con = psycopg2.connect(database = dbname, user = username, host='localhost', password=pswd)

# %%
# query:
#sql_query = """
#SELECT * FROM course_data_table WHERE num_reviews > 500 ORDER BY avg_rating DESC LIMIT 5;
#"""
skill = 'exceld'
sql_query = "SELECT * FROM course_data_table WHERE (title LIKE '% "+skill+" %') ORDER BY num_reviews DESC LIMIT 5;"


course_data_from_sql = pd.read_sql_query(sql_query,con)

course_data_from_sql
# Out:
# Empty DataFrame
# Columns: [index, Unnamed: 0.1, avg_rating, description, headline, homepage, image, num_reviews, title, cleaned_description]
# Index: []

# %%
course_data = pd.DataFrame.from_csv('udemy_courses_cleaned.csv')

# %%
for i in range(course_data.shape[0]):
    course_data.title[i] = course_data.title[i].lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-ebc6e63ea252> in <module>()
# ----> 1 course_data.title.lower()
#
# /Users/swang/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'lower'

# %%
course_data.title = course_data.title.apply(lambda d: d.lower())

# %%
course_data
# Out:
#       Unnamed: 0.1  avg_rating  \
# 0                0     4.14286
# 1                1     4.60000
# 2                2     3.65625
# 3                3     2.00000
# 4                4     4.28680
# 5                5     4.25000
# 6                6     4.33333
# 7                7     4.42857
# 8                8     4.50000
# 9                9     4.33333
# 10              10     5.00000
# 11              11     4.38889
# 12              12     4.50000
# 13              13     5.00000
# 14              14     4.41071
# 15              15     2.72727
# 16              16     4.61111
# 17              17     4.06522
# 18              18     4.22059
# 19              19     4.31361
# 20              20     4.35035
# 21              21     1.00000
# 22              22     1.00000
# 23              23     4.25000
# 24              24     4.39130
# 25              25     3.25000
# 26              26     3.91925
# 27              27     3.85000
# 28              28     3.78261
# 29              29     0.75000
# ...            ...         ...
# 3938          3938     3.53571
# 3939          3939     4.56250
# 3940          3940     0.00000
# 3941          3941     4.50000
# 3942          3942     2.50000
# 3943          3943     4.83333
# 3944          3944     2.40000
# 3945          3945     4.13636
# 3946          3946     4.42857
# 3947          3947     4.41111
# 3948          3948     4.06522
# 3949          3949     4.04167
# 3950          3950     4.25000
# 3951          3951     2.75000
# 3952          3952     4.83333
# 3953          3953     3.98507
# 3954          3954     4.66667
# 3955          3955     2.62500
# 3956          3956     3.94444
# 3957          3957     3.72984
# 3958          3958     4.50000
# 3959          3959     1.90000
# 3960          3960     4.05172
# 3961          3961     4.13636
# 3962          3962     4.29545
# 3963          3963     3.85000
# 3964          3964     4.62500
# 3965          3965     0.00000
# 3966          3966     4.45385
# 3967          3967     4.29630
#
#                                             description  \
# 0          In this Fast Start course we'll look at s...
# 1     Don't  struggle with many hours of learning co...
# 2      Learn from scratch how to make awesome iPhone...
# 3     BONUS!!!!YOU GET 176 GAME READY IMAGES WITH TH...
# 4     This course is the beginning track for certifi...
# 5     This course is designed to be a quick start ov...
# 6     *** No Previous Programming Experience Necessa...
# 7          More than 400 students have enrolled ! do...
# 8       \t  Welcome to this Mysql course.     \t  If...
# 9     \n \n How about creating an E-commerce mobile ...
# 10     Knockout is a JavaScript MVVM (Model View Vie...
# 11    In this course, we will take your Java skills ...
# 12    Editing HTML code is still very valuable in an...
# 13    In this course, you will learn how to create y...
# 14    This course is an essential for Web Developers...
# 15    Learn the basic concepts and necessary scripti...
# 16    Interested in speeding up your WordPress theme...
# 17    Update: Code updated for Swift 3 and the lates...
# 18    LATEST UPDATE: October, 2015If you've been str...
# 19    *This is a course designed to help you with th...
# 20      \t      Coupons and updates on twitter, foll...
# 21      \tREAD ON !     \t            --------------...
# 22      \t   This video course provides invaluable i...
# 23      \t    Regular expression is one of the funda...
# 24     Covers App creation for iOS 8 and Android L  ...
# 25    use code get50 to get 50% discount\nCascading ...
# 26    \t First of all let me tell you what is Open C...
# 27    This course is a library of effective and prov...
# 28      \t    This course teaches you Hadoop, Pig, H...
# 29    Subtitles are available for Introduction, Case...
# ...                                                 ...
# 3938   Receive a verifiable certificate of completio...
# 3939    \t This course gives you the source code to ...
# 3940   New Wordpress development for your web design...
# 3941   Have you ever thought of a cool idea for an a...
# 3942  This course will cover how to make games in th...
# 3943  ***FREE Bonus Plugin Special is here!***I’m gi...
# 3944  TYPO3 is a free and open source web content ma...
# 3945  Bugzilla is an extremely popular, browser base...
# 3946  Designed for beginners, this course teaches yo...
# 3947  The complete Laravel course to be a profession...
# 3948  ****INCLUDES UPDATED SOURCE PROJECTS FOR SWIFT...
# 3949  What is this course about? This course is a pr...
# 3950  This course has been created for developers in...
# 3951  Have you ever wanted to learn to code but don’...
# 3952  In WordPress Menu, the latest of my WordPress ...
# 3953  ⇉ Watch the promo video to see How You Build Y...
# 3954  Learn Javascript the simple way!  This course ...
# 3955  Would you like to be a ODI/ETL Developer with ...
# 3956  Acutal price of the course may hike soon, Join...
# 3957  Note: Price will hike soon, this is just intro...
# 3958  With the ever-growing  popularity of social ne...
# 3959   Rapid Cassandra is a practical video course t...
# 3960  Last updated: June 30, 2015.By the completion ...
# 3961    \t                This course will guide you...
# 3962  ** The course was last updated on August 2015....
# 3963  Course updated: October 2015Use these various ...
# 3964    \t  We all know the benefits of a membership...
# 3965  This is a perfect course for designers who kno...
# 3966  BONUS section added for changing levels on web...
# 3967     Welcome to this Oracle Rman course !!    \t...
#
#                                                headline  \
# 0     Sneak peek into new features of iOS7 and Xcode...
# 1     In this course you will learn how to develop i...
# 2     All the teachings and source code from this co...
# 3     Learn how to make games without writing a sing...
# 4     Learn the fundamentals of programming in this ...
# 5     Get started building your own websites using J...
# 6     Go from having zero experience in programming ...
# 7        9 Questions Every E-Commerce Newbie Should Ask
# 8     As Oracle dataguard, let setup a Mysqk rReplic...
# 9     This course demonstrates concepts for creating...
# 10    Create a complete and structured single page a...
# 11    Be an expert in Java with this great course wh...
# 12    Learn how to easily create HTML websites, Word...
# 13    A Step-By-Step Guide To Creating Your Own Webs...
# 14    Start developing apps for Android & iOS just b...
# 15    A-Z Guide how to create word and letter based ...
# 16    Learn how to utilize over 20 powerful custom f...
# 17    Detailed video lectures that take you step by ...
# 18    In this comprehensive course I'll show you how...
# 19    Alex Gimson (importio evangelist) is going to ...
# 20    Android tutorial for all level students. Learn...
# 21    This course is the complete guidance for doing...
# 22    Build an app using CoffeeScript with one-third...
# 23    Learn a solid background of Regular Expression...
# 24    Learn how to create games for both Android and...
# 25    Learn how to use cascading style sheets for ma...
# 26    Face Detection - Digital Image Processing and ...
# 27    Your Guide To Successful Apps based On Real Wo...
# 28    Learn Hadoop, Pig, Hive and Mahout with a hand...
# 29    Learn best practices of software design to pro...
# ...                                                 ...
# 3938  Learn how to setup and deploy a Meteor web app...
# 3939  Be an entrepreneur! Use the same tools as prog...
# 3940  How to build an online business website by usi...
# 3941  Make iOS, Android and web apps using HTML, CSS...
# 3942  In this course you will learn the ins and outs...
# 3943  Master building product grids with WordPress, ...
# 3944  Learn TYPO3! and build sophisticated websites ...
# 3945  Learn Bugzilla Software Testing Tool to increa...
# 3946                  A beginners guide to HTML and CSS
# 3947  Create professional web projects with Laravel ...
# 3948  Create limitless levels in a variety of projec...
# 3949  Start to accept credit cards on your PHP web s...
# 3950  Learn how to start using ECMAScript 6 (ES6) fo...
# 3951  Learning to code C#?  We have 21 applications ...
# 3952  WordPress Theme Customization 103 teaches you ...
# 3953  In this course students will learn a complete ...
# 3954  Learn Javascript by applying it right away.  E...
# 3955  Find out how to become an Expert  Data warehou...
# 3956  Learn Object Oriented Programming in C++ using...
# 3957  Learn complete python and ruby programming lan...
# 3958  Learn How To Set Up Your Own Social Network St...
# 3959  Learn how to design a NoSQL database using Cas...
# 3960  Building Strong Foundation to Resize your Know...
# 3961  Build powerful and modern web apps that run sm...
# 3962  Flash course! Learn how to turn your Wordpress...
# 3963  Quickly produce quality iOS and Android apps w...
# 3964  A step-by-step course on setting up a membersh...
# 3965  Learn these five techniques of jQuery and you ...
# 3966  Learn from a pro how to develop games with gam...
# 3967  This is a practice course. Here you'll find a ...
#
#                                                homepage  \
# 0            www.udemy.com/ios7-programming-fast-start/
# 1                            www.udemy.com/appsinxcode/
# 2                  www.udemy.com/ios-7-app-development/
# 3     www.udemy.com/make-iphone-and-ipad-games-in-1-...
# 4                       www.udemy.com/cwc-introduction/
# 5     www.udemy.com/cwjoomla-a-quickstart-introduction/
# 6     www.udemy.com/c-programming-made-easy-in-60-mi...
# 7     www.udemy.com/how-to-make-money-online-by-sell...
# 8     www.udemy.com/mysql-master-and-slave-replication/
# 9     www.udemy.com/build-e-commerce-mobile-apps-wit...
# 10    www.udemy.com/building-a-single-page-web-appli...
# 11    www.udemy.com/using-java-for-advanced-applicat...
# 12                       www.udemy.com/dreamweaver-ftp/
# 13    www.udemy.com/create-your-own-website-using-yo...
# 14    www.udemy.com/getting-started-with-ionic-frame...
# 15                       www.udemy.com/word-game-unity/
# 16    www.udemy.com/ignite-wordpress-theme-developme...
# 17    www.udemy.com/program-a-pro-iphone-memory-game...
# 18    www.udemy.com/how-to-build-a-website-from-scra...
# 19      www.udemy.com/how-to-extract-data-from-the-web/
# 20    www.udemy.com/android-tutorial-from-beginner-t...
# 21    www.udemy.com/c-programming-from-scratch-to-ad...
# 22    www.udemy.com/building-an-application-with-cof...
# 23    www.udemy.com/java-regular-expression-foundation/
# 24    www.udemy.com/mobile-game-development-with-cor...
# 25                    www.udemy.com/css-for-beginners2/
# 26    www.udemy.com/learn-open-cv-with-microsoft-vis...
# 27                              www.udemy.com/app-labs/
# 28           www.udemy.com/big-data-hadoop-masterclass/
# 29         www.udemy.com/design-patterns-through-swift/
# ...                                                 ...
# 3938                       www.udemy.com/meteor-course/
# 3944                                       typo3 basics
# 3945           bugzilla: software test management tool
# 3946                  learn how to build webpages fast!
# 3947    learn laravel: create your web app step-by-step
# 3948           endless worlds with swift and sprite kit
# 3949           learn stripe php: make checkout webpages
# 3950                     upgrade your javascript to es6
# 3951      programming for beginners in c# windows forms
# 3952  how to create a wordpress menu driven site & blog
# 3953  the complete wordpress course - build your own...
# 3954  simple javascript: learn by doing, beginners w...
# 3955     odi 12c all steps - become a odi/etl developer
# 3956                       learn oop in c++ programming
# 3957  python and ruby programming complete step-by-s...
# 3958        learn how to create your own social network
# 3959                                    rapid cassandra
# 3960    learning 200 jquery functions with 800 examples
# 3961       learning express web application development
# 3962  wordpress to app - turn your website into an a...
# 3963  mobile app development: make ios & android app...
# 3964  how to create a membership site with wordpress...
# 3965                jquery for designers and beginners
# 3966  develop your own game quick & easy with game m...
# 3967                          practice with oracle rman
#
#                                     cleaned_description
# 0          in this fast start course we ll look at s...
# 1     don t  struggle with many hours of learning co...
# 2      learn from scratch how to make awesome iphone...
# 3     bonus    you get     game ready images with th...
# 4     this course is the beginning track for certifi...
# 5     this course is designed to be a quick start ov...
# 6         no previous programming experience necessa...
# 7          more than     students have enrolled   do...
# 8          welcome to this mysql course.        if y...
# 9         how about creating an e commerce mobile ap...
# 10     knockout is a javascript mvvm  model view vie...
# 11    in this course  we will take your java skills ...
# 12    editing html code is still very valuable in an...
# 13    in this course  you will learn how to create y...
# 14    this course is an essential for web developers...
# 15    learn the basic concepts and necessary scripti...
# 16    interested in speeding up your wordpress theme...
# 17    update   code updated for swift 3 and the late...
# 18    latest update  october      if you ve been str...
# 19     this is a course designed to help you with th...
# 20             coupons and updates on twitter  follo...
# 21       read on                                    ...
# 22          this video course provides invaluable in...
# 23           regular expression is one of the fundam...
# 24     covers app creation for ios   and android l  ...
# 25    use code  get   to get     discount cascading ...
# 26      first of all let me tell you what is open cv...
# 27    this course is a library of effective and prov...
# 28           this course teaches you hadoop  pig  hi...
# 29    subtitles are available for introduction  case...
# ...                                                 ...
# 3938   receive a verifiable certificate of completio...
# 3939      this course gives you the source code to c...
# 3940   new wordpress development for your web design...
# 3941   have you ever thought of a cool idea for an a...
# 3942  this course will cover how to make games in th...
# 3943     free bonus plugin  special is here    i   m...
# 3944  typo3 is a free and open source web content ma...
# 3945  bugzilla is an extremely popular  browser base...
# 3946  designed for beginners  this course teaches yo...
# 3947  the complete laravel course to be a profession...
# 3948      includes  updated  source  projects  for  ...
# 3949  what is this course about  this course is a pr...
# 3950  this course has been created for developers in...
# 3951  have you ever wanted to learn to code but don ...
# 3952  in wordpress menu  the latest of my wordpress ...
# 3953      watch the promo video to see how you build...
# 3954  learn javascript the simple way   this course ...
# 3955  would you like to be a odi etl developer with ...
# 3956  acutal price of the course may hike soon  join...
# 3957  note  price will hike soon  this is just intro...
# 3958  with the ever growing  popularity of social ne...
# 3959   rapid cassandra is a practical video course t...
# 3960  last updated  june 3       .by the completion ...
# 3961                     this course will guide you ...
# 3962     the course was last updated on august     ....
# 3963  course updated  october     use these various ...
# 3964       we all know the benefits of a membership ...
# 3965  this is a perfect course for designers who kno...
# 3966  bonus section added for changing levels on web...
# 3967     welcome to this oracle rman course         ...
#
# [3968 rows x 9 columns]
