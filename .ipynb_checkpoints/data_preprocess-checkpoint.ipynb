# %%
import itertools
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import time
import nltk
from nltk.stem import WordNetLemmatizer

import pickle
from gensim import corpora, models, similarities

import psycopg2
import pandas as pd
import numpy as np
from collections import Counter

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
SF = pd.read_csv('./data/SF_jobs.csv')
#NYC = pd.read_csv('./data/SF_jobs.csv')
#Seattle = pd.read_csv('./data/SF_jobs.csv')
SF.drop('Unnamed: 0',axis=1,inplace=True)

# %%
SF
# Out:
#                               comp_name  \
# 0                   Rodan + Fields, LLC
# 1                               Verizon
# 2                            Ten-X, LLC
# 3                               Verizon
# 4                           VDart, Inc.
# 5                           CyberCoders
# 6                           CyberCoders
# 7                           CyberCoders
# 8                    Redfish Technology
# 9                 Openmind Technologies
# 10                 Nextphase Recruiting
# 11                                  SAP
# 12                          CyberCoders
# 13                          CyberCoders
# 14                          CyberCoders
# 15                     BayOne Solutions
# 16                          CyberCoders
# 17               Robert Half Technology
# 18                            Genesis10
# 19                          CyberCoders
# 20                          CyberCoders
# 21                      Net2Source Inc.
# 22                     IDC Technologies
# 23                   Mumba Technologies
# 24                              OmniPro
# 25                          Accelon Inc
# 26             Somasoft Solutions. Inc.
# 27                      TechSophy, Inc.
# 28               Quality IT Source, LLC
# 29                      The Judge Group
# ...                                 ...
# 1517                     Kelly Services
# 1518                     Latitude36 Inc
# 1519                     Incorporan Inc
# 1520                      RHP Soft Inc.
# 1521          Intelliswift Software Inc
# 1522                            Droisys
# 1523                Xoriant Corporation
# 1524  CSI (Consultant Specialists Inc.)
# 1525                  Knack Systems LLC
# 1526           Alpha Net Consulting LLC
# 1527              Infolob Solutions Inc
# 1528            ATR International, Inc.
# 1529                   BayOne Solutions
# 1530                              Modis
# 1531                 Guidewire Software
# 1532                 Skyrocket Ventures
# 1533                    Net2Source Inc.
# 1534                   BayOne Solutions
# 1535                 Talent Space, Inc.
# 1536                          Data Exel
# 1537                          Data Exel
# 1538                          Data Exel
# 1539                  Data Incorporated
# 1540          Productive Data Solutions
# 1541          Cogent Data Solutions Llc
# 1542                   DCM Data Systems
# 1543                   DCM Data Systems
# 1544                   DCM Data Systems
# 1545                 Data Intensity LLC
# 1546                   DCM Data Systems
#
#                                         job_description  \
# 0      The Opportunity Are you passionate about mini...
# 1      Responsibilities   Stay on the front lines of...
# 2      Senior Data Scientist   Commercial Business  ...
# 3      Responsibilities Stay on the front lines of g...
# 4      VDart is global  emerging information technol...
# 5         Minimum Required Skills Data Scientist  Ma...
# 6         Minimum Required Skills  Startup Experienc...
# 7         Minimum Required Skills  Startup Experienc...
# 8      Data Scientist  Ed Tech Startup Location  San...
# 9      Our Client has built the world s most powerfu...
# 10      Phd in a quantitative field is a requirement...
# 11        SAP is the world leader in enterprise appl...
# 12        Minimum Required Skills Machine Learning  ...
# 13        Minimum Required Skills Machine Learning  ...
# 14        Minimum Required Skills Data Science  Arti...
# 15     Title  Lead Data Scientist  Applied Researche...
# 16        Minimum Required Skills Machine Learning  ...
# 17     Data Scientist Hands on responsibility as par...
# 18     Genesis   is currently seeking a Senior Data ...
# 19        Minimum Required Skills Signal processing ...
# 20        Minimum Required Skills Python R  Scala  H...
# 21     Net Source  Inc. is one of the fastest growin...
# 22     MUST have adtech experience.We are developing...
# 23     Hello All We re currently hiring for a great ...
# 24     CONSULTANT REQUEST FORDATA SCIENTISTUnder the...
# 25     Looking for a Data Scientist for our client i...
# 26          Data Scientist  LOC San Francisco Bay Ar...
# 27     Role  Data Scientist   Staff EngineerLocation...
# 28       In depth knowledge and experience using and...
# 29     Our client is currently seeking a DATA SCIENT...
# ...                                                 ...
# 1517           Must be legally authorized to work in...
# 1518   Title  QA Test Analyst 3 Location  Foster Cit...
# 1519   INCORPORAN INC is looking for strong Java Dev...
# 1520   Hi Our client in San Francisco California is ...
# 1521   While applying please mention  SG BSA Complia...
# 1522   Please share me resume at raj droisys.comHell...
# 1523   Position Title  Linux System AdministratorLoc...
# 1524   Duties  The person in this position will be r...
# 1525   Position  SAP BI  HANA ArchitectLocation  Bay...
# 1526   Role  eDiscovery Consultant Location  Menlo P...
# 1527   Position  Senior SQL DBA with Oracle Experien...
# 1528   ATR       Oakland  CA Instructional  Speciali...
# 1529    This Position is applicable for Local to Cal...
# 1530   Modis  client has a long term contract opport...
# 1531   We re looking for talented and intellectually...
# 1532   Skyrocket Ventures is a recruiting firm for h...
# 1533   Hi I trust you are doing great.This is Ramky ...
# 1534   We are looking for a DevOps Engineer coming f...
# 1535   Talent Space Inc is looking for Project Manag...
# 1536    Client is not entertaining profile less then...
# 1537   Urgent opening for SSRS Developer    Newark  ...
# 1538   Position  Facets Consultant    Facets LeadLoc...
# 1539   We are looking for C C++  Java  Python Consul...
# 1540   The Ideal Candidate You enjoy building simple...
# 1541   I wanted to see if you may know of someone  I...
# 1542   Job RequirementsBitmap. Be a part of the UX t...
# 1543   Qualifications   Requirements           years...
# 1544   Job Description  Overall experience of   + ye...
# 1545   Role  Oracle Financial FunctionalOracle Finan...
# 1546   Responsibilities  Overall program delivery pl...
#
#                  job_location      job_posted  \
# 0           San Francisco, CA     3 weeks ago
# 1               Palo Alto, CA     9 hours ago
# 2                 Belmont, CA      1 hour ago
# 3               Palo Alto, CA     9 hours ago
# 4           San Francisco, CA     4 hours ago
# 5               San Mateo, CA    15 hours ago
# 6           San Francisco, CA    15 hours ago
# 7           San Francisco, CA    15 hours ago
# 8           San Francisco, CA     2 weeks ago
# 9           San Francisco, CA      1 week ago
# 10           Redwood City, CA     2 weeks ago
# 11                  Palo Alto     8 hours ago
# 12          San Francisco, CA    15 hours ago
# 13              San Mateo, CA    15 hours ago
# 14              San Mateo, CA    15 hours ago
# 15          San Francisco, CA      3 days ago
# 16           Redwood City, CA    15 hours ago
# 17          San Francisco, CA  26 minutes ago
# 18          San Francisco, CA     2 hours ago
# 19               Berkeley, CA    15 hours ago
# 20              San Mateo, CA    15 hours ago
# 21          San Francisco, CA      3 days ago
# 22              San Mateo, CA       1 day ago
# 23              Palo Alto, CA      1 week ago
# 24               Martinez, CA      1 week ago
# 25          San Francisco, CA      2 days ago
# 26          San Francisco, CA    15 hours ago
# 27              Palo Alto, CA      1 week ago
# 28              Palo Alto, CA      2 days ago
# 29          San Francisco, CA     7 hours ago
# ...                       ...             ...
# 1517           Emeryville, CA    18 hours ago
# 1518          Foster City, CA       1 day ago
# 1519        San Francisco, CA    13 hours ago
# 1520        San Francisco, CA    12 hours ago
# 1521              Concord, CA    11 hours ago
# 1522           Burlingame, CA    11 hours ago
# 1523            Palo Alto, CA    10 hours ago
# 1524  South San Francisco, CA    10 hours ago
# 1525        San Francisco, CA     7 hours ago
# 1526           Menlo Park, CA     4 hours ago
# 1527            Palo Alto, CA     5 hours ago
# 1528              Oakland, CA     3 hours ago
# 1529        San Francisco, CA     2 hours ago
# 1530        San Francisco, CA   5 minutes ago
# 1531          Foster City, CA      1 week ago
# 1532        San Francisco, CA    20 hours ago
# 1533        San Francisco, CA     5 hours ago
# 1534        San Francisco, CA      4 days ago
# 1535        San Francisco, CA     2 weeks ago
# 1536           Pleasanton, CA    14 hours ago
# 1537               Newark, CA      2 days ago
# 1538        San Francisco, CA      2 days ago
# 1539        San Francisco, CA      3 days ago
# 1540        San Francisco, CA      1 week ago
# 1541        San Francisco, CA     3 weeks ago
# 1542        San Francisco, CA    12 hours ago
# 1543            San Ramon, CA    12 hours ago
# 1544        San Francisco, CA    12 hours ago
# 1545        San Francisco, CA    13 hours ago
# 1546        San Francisco, CA    12 hours ago
#
#                                               job_title
# 0                                        Data Scientist
# 1                                        Data Scientist
# 2                                 Senior Data Scientist
# 3                                 Senior Data Scientist
# 4                                        Data Scientist
# 5     Data Scientist (Machine Learning, Computer Vis...
# 6                                 Senior Data Scientist
# 7                                 Senior Data Scientist
# 8                                        Data Scientist
# 9             Senior Data Scientist (Machine Learning )
# 10                                       Data Scientist
# 11    Senior Data Scientist - SAP Innovation Center ...
# 12    Data Scientist - Machine Learning, Python, Dat...
# 13                                Senior Data Scientist
# 14                Data Scientist (AI, Machine Learning)
# 15                               Lead/Sr Data Scientist
# 16                                Senior Data Scientist
# 17                                       Data Scientist
# 18                                  Data Scientist, Sr.
# 19                    Data Scientist - Startup + Equity
# 20                                Data Scientist- Scala
# 21                                       Data Scientist
# 22                                       Data Scientist
# 23                                   Sr. Data Scientist
# 24                                       Data Scientist
# 25                                       Data Scientist
# 26                                       DATA SCIENTIST
# 27                                       Data Scientist
# 28                    Sr. Data Analytics/Data Scientist
# 29                                  DATA SCIENTIST, SR.
# ...                                                 ...
# 1517           IT Business Analyst (I) - Emeryville, CA
# 1518                QA Test Analyst 3 @ Foster City, CA
# 1519        Java Developer with Code Coverage tools exp
# 1520  Senior iOS Developer ( local to bay area candi...
# 1521  Business Systems Analyst w/ DW and regulatory exp
# 1522      Fulltime Java Quality Engineer // Locals Only
# 1523  Linux System Administrator (Local candidates o...
# 1524                  Senior Contract Associate 5929164
# 1525  SAP BI/ HANA Architect position for a year lon...
# 1526  Ediscovery Technical Consultant for Facebook i...
# 1527  Senior SQL DBA with Oracle (10 - 12 Years of E...
# 1528       Instructional Specialist PMO Training PM *w2
# 1529        Sr. UI Developer - F2F Interview in CA Must
# 1530  Internal Communications Specialist role in San...
# 1531  Principal Technical Writer (Developer Document...
# 1532  Lead Node.js Software Engineer / Architect (up...
# 1533  Technology Lead - Java DevOps @ San Francisco, CA
# 1534  Developers looking to make career into DevOPS ...
# 1535  Project Manager/Scrum Master (W2 Candidates only)
# 1536                                     Java Developer
# 1537                                     SSRS Developer
# 1538        Facets Consultant Healthcare // Facets Lead
# 1539  C/C++//Java//Python Consultant with SQL,Hadoop...
# 1540                            Sr. Front End Developer
# 1541                                   Network Engineer
# 1542                                    Visual Designer
# 1543                                       UI Developer
# 1544       NLP/Machine Learning (ML) Developer - Senior
# 1545                   Oracle Apps Financial Functional
# 1546                               Program Manager - IT
#
# [1547 rows x 5 columns]

# %%
#Functions for data cleaning
wnl = WordNetLemmatizer()

def text_cleaner(text):
    
    text = text.lower().split()
    text = [wnl.lemmatize(myWord) for myWord in text] # Lemmertization

    stop_words = set(stopwords.words("english")) # Filter out any stop words
    text = [w for w in text if not w in stop_words]
    
    return text # return list of tokens

# %%
def text_preprocess(line): # perform tokenization, select noun, Lemmertization etc on a line text

    rtext=[]    
    for w, tag in nltk.pos_tag(nltk.word_tokenize(line.lower())):  # Tokenization
        if tag in ['NN']:  # Keep only Nouns (for this special case)
            rtext.append(w)
    
    wordnet_lemmatizer = WordNetLemmatizer()  # Lemmertization
    rtext = [wordnet_lemmatizer.lemmatize(w) for w in rtext]
            
    stop_words = set(stopwords.words("english")) # Filter out any stop words
    rtext = [w for w in rtext if not w in stop_words]
    
    return rtext

# %%
text = []

# %%
for i in range (SF.shape[0]):
    text = text + text_preprocess(SF.job_description[i])

# %%
len(text)
# Out:
# 183912

# %%
counts = Counter(text)

# %%
import operator

frequency = sorted(counts.items(), key=operator.itemgetter(1),reverse=True)

# %%
frequency[:1000]
# Out:
# [('experience', 6834),
#  ('business', 3225),
#  ('development', 2747),
#  ('team', 2192),
#  ('management', 2162),
#  ('knowledge', 1869),
#  ('software', 1825),
#  ('ability', 1735),
#  ('design', 1731),
#  ('position', 1411),
#  ('work', 1406),
#  ('security', 1329),
#  ('project', 1321),
#  ('technology', 1301),
#  ('support', 1218),
#  ('information', 1189),
#  ('system', 1160),
#  ('resume', 1021),
#  ('application', 1010),
#  ('job', 995),
#  ('product', 986),
#  ('network', 940),
#  ('analysis', 930),
#  ('communication', 919),
#  ('environment', 900),
#  ('understanding', 891),
#  ('test', 885),
#  ('performance', 877),
#  ('engineering', 853),
#  ('client', 833),
#  ('computer', 819),
#  ('time', 793),
#  ('company', 789),
#  ('quality', 789),
#  ('opportunity', 789),
#  ('customer', 781),
#  ('employment', 781),
#  ('engineer', 764),
#  ('service', 717),
#  ('process', 715),
#  ('level', 713),
#  ('web', 683),
#  ('science', 670),
#  ('java', 660),
#  ('status', 654),
#  ('infrastructure', 653),
#  ('role', 649),
#  ('platform', 638),
#  ('integration', 636),
#  ('degree', 629),
#  ('implementation', 618),
#  ('sql', 609),
#  ('end', 589),
#  ('database', 581),
#  ('enterprise', 563),
#  ('industry', 550),
#  ('architecture', 546),
#  ('please', 532),
#  ('code', 504),
#  ('eligibility', 493),
#  ('compliance', 491),
#  ('production', 490),
#  ('problem', 487),
#  ('organization', 472),
#  ('manager', 467),
#  ('automation', 447),
#  ('identity', 440),
#  ('disability', 436),
#  ('data', 434),
#  ('world', 432),
#  ('leadership', 432),
#  ('oracle', 432),
#  ('etc', 426),
#  ('python', 421),
#  ('candidate', 418),
#  ('document', 414),
#  ('documentation', 414),
#  ('server', 403),
#  ('developer', 398),
#  ('cloud', 392),
#  ('expertise', 391),
#  ('solution', 387),
#  ('minimum', 381),
#  ('building', 377),
#  ('training', 376),
#  ('color', 375),
#  ('race', 373),
#  ('origin', 373),
#  ('word', 366),
#  ('consideration', 361),
#  ('javascript', 360),
#  ('religion', 359),
#  ('deloitte', 355),
#  ('life', 354),
#  ('email', 352),
#  ('configuration', 347),
#  ('regard', 347),
#  ('analyst', 346),
#  ('strategy', 341),
#  ('reporting', 337),
#  ('program', 335),
#  ('risk', 331),
#  ('field', 329),
#  ('planning', 328),
#  ('delivery', 327),
#  ('research', 325),
#  ('detail', 321),
#  ('administration', 319),
#  ('machine', 315),
#  ('department', 311),
#  ('law', 308),
#  ('marketing', 308),
#  ('description', 307),
#  ('sex', 305),
#  ('career', 305),
#  ('center', 301),
#  ('bank', 299),
#  ('part', 297),
#  ('core', 296),
#  ('intelligence', 295),
#  ('vision', 294),
#  ('contract', 294),
#  ('change', 293),
#  ('office', 288),
#  ('lead', 286),
#  ('francisco', 285),
#  ('hadoop', 282),
#  ('user', 280),
#  ('source', 279),
#  ('fit', 275),
#  ('day', 270),
#  ('staff', 269),
#  ('location', 268),
#  ('today', 268),
#  ('deployment', 267),
#  ('right', 263),
#  ('impact', 262),
#  ('stack', 261),
#  ('hardware', 260),
#  ('verification', 258),
#  ('growth', 258),
#  ('form', 257),
#  ('maintenance', 255),
#  ('testing', 254),
#  ('year', 253),
#  ('click', 252),
#  ('area', 251),
#  ('link', 248),
#  ('monitoring', 245),
#  ('use', 243),
#  ('market', 239),
#  ('education', 237),
#  ('bottom', 236),
#  ('hire.copyright', 235),
#  ('employerall', 235),
#  ('law.your', 235),
#  ('access', 232),
#  ('culture', 230),
#  ('learning', 229),
#  ('state', 227),
#  ('u.s.please', 227),
#  ('control', 226),
#  ('scale', 225),
#  ('unit', 224),
#  ('background', 223),
#  ('collaboration', 223),
#  ('health', 219),
#  ('bachelor', 213),
#  ('b', 211),
#  ('site', 210),
#  ('success', 210),
#  ('spark', 208),
#  ('plan', 204),
#  ('group', 204),
#  ('cross', 203),
#  ('manage', 202),
#  ('guidance', 197),
#  ('framework', 197),
#  ('variety', 196),
#  ('storage', 196),
#  ('gender', 193),
#  ('employer', 191),
#  ('c', 191),
#  ('processing', 187),
#  ('architect', 186),
#  ('html', 183),
#  ('r', 182),
#  ('fast', 181),
#  ('partner', 180),
#  ('availability', 180),
#  ('focus', 178),
#  ('familiarity', 176),
#  ('practice', 175),
#  ('finance', 172),
#  ('cycle', 172),
#  ('programming', 171),
#  ('rest', 171),
#  ('vendor', 171),
#  ('improvement', 169),
#  ('assurance', 165),
#  ('talent', 165),
#  ('release', 164),
#  ('value', 163),
#  ('optimization', 162),
#  ('k', 161),
#  ('direction', 160),
#  ('review', 159),
#  ('model', 159),
#  ('base', 158),
#  ('record', 158),
#  ('language', 155),
#  ('master', 154),
#  ('resource', 154),
#  ('certification', 154),
#  ('resolution', 154),
#  ('term', 153),
#  ('firm', 152),
#  ('orientation', 152),
#  ('decision', 152),
#  ('plus', 152),
#  ('innovation', 151),
#  ('linux', 150),
#  ('expert', 150),
#  ('leader', 150),
#  ('city', 149),
#  ('e.g', 149),
#  ('party', 148),
#  ('warehouse', 148),
#  ('scalability', 146),
#  ('maintain', 146),
#  ('activity', 146),
#  ('person', 145),
#  ('basis', 145),
#  ('etl', 144),
#  ('validation', 144),
#  ('act', 143),
#  ('execution', 143),
#  ('title', 142),
#  ('presentation', 141),
#  ('agile', 140),
#  ('banking', 139),
#  ('integrity', 139),
#  ('scientist', 139),
#  ('order', 138),
#  ('track', 138),
#  ('edge', 136),
#  ('consulting', 134),
#  ('reliability', 134),
#  ('bi', 133),
#  ('equipment', 133),
#  ('j', 132),
#  ('proficiency', 131),
#  ('e', 131),
#  ('suite', 131),
#  ('consultant', 130),
#  ('range', 129),
#  ('spring', 128),
#  ('age', 128),
#  ('compensation', 128),
#  ('volume', 128),
#  ('load', 127),
#  ('passion', 127),
#  ('class', 127),
#  ('interface', 126),
#  ('ruby', 126),
#  ('ad', 124),
#  ('governance', 124),
#  ('san', 123),
#  ('attention', 123),
#  ('member', 123),
#  (u'cs', 122),
#  ('salesforce', 121),
#  ('capacity', 121),
#  ('scope', 120),
#  ('assistance', 120),
#  ('object', 119),
#  ('power', 119),
#  ('relationship', 119),
#  ('sap', 118),
#  ('transformation', 118),
#  ('scala', 118),
#  ('portfolio', 118),
#  ('api', 118),
#  ('generation', 117),
#  ('community', 115),
#  ('methodology', 114),
#  ('employee', 113),
#  ('addition', 113),
#  ('startup', 112),
#  ('audit', 112),
#  ('implement', 112),
#  ('contact', 111),
#  (u'algorithm', 110),
#  ('solving', 110),
#  ('mission', 110),
#  ('accounting', 109),
#  ('action', 109),
#  ('lifecycle', 109),
#  ('installation', 109),
#  ('creation', 109),
#  ('cisco', 108),
#  ('ip', 108),
#  ('multi', 107),
#  ('caduration', 107),
#  ('future', 106),
#  ('way', 105),
#  ('insurance', 105),
#  ('report', 105),
#  ('excel', 104),
#  ('responsibility', 104),
#  ('qa', 104),
#  ('line', 103),
#  ('apis', 103),
#  ('skill', 102),
#  ('university', 101),
#  ('efficiency', 101),
#  ('side', 101),
#  ('tool', 101),
#  ('budget', 100),
#  ('matter', 100),
#  ('i.e', 99),
#  ('need', 99),
#  ('credit', 99),
#  ('build', 99),
#  ('individual', 99),
#  ('c++', 98),
#  ('cost', 98),
#  ('mail', 98),
#  ('someone', 98),
#  ('interview', 97),
#  ('search', 97),
#  ('mysql', 96),
#  ('veteran', 96),
#  ('thinking', 96),
#  ('shell', 96),
#  ('recovery', 95),
#  ('domain', 95),
#  ('self', 95),
#  ('function', 94),
#  ('manner', 94),
#  ('exposure', 93),
#  ('judgment', 93),
#  ('internet', 92),
#  ('palo', 92),
#  ('help', 92),
#  ('healthcare', 92),
#  ('consumer', 92),
#  ('cassandra', 92),
#  ('voice', 92),
#  ('visualization', 91),
#  ('jquery', 91),
#  ('functionality', 91),
#  ('date', 90),
#  ('bonus', 90),
#  ('privacy', 90),
#  ('networking', 90),
#  ('modeling', 90),
#  ('response', 90),
#  ('capital', 90),
#  ('video', 89),
#  ('fortune', 89),
#  ('structure', 89),
#  ('coordination', 89),
#  ('point', 89),
#  ('equity', 89),
#  ('desire', 88),
#  ('content', 88),
#  ('director', 87),
#  ('care', 87),
#  ('threat', 87),
#  ('completion', 87),
#  ('policy', 87),
#  ('desktop', 86),
#  ('requirement', 86),
#  ('call', 86),
#  ('migration', 85),
#  ('hr', 85),
#  ('phone', 85),
#  ('package', 84),
#  ('task', 84),
#  ('brand', 84),
#  ('inc.', 84),
#  ('share', 83),
#  ('executive', 83),
#  ('goal', 83),
#  ('travel', 82),
#  ('player', 82),
#  ('ownership', 82),
#  ('standard', 82),
#  ('alto', 82),
#  ('create', 82),
#  ('assessment', 82),
#  ('roadmap', 82),
#  ('soap', 81),
#  ('interest', 81),
#  ('azure', 81),
#  ('excellence', 81),
#  ('monitor', 81),
#  ('backend', 81),
#  ('account', 81),
#  ('mentor', 81),
#  ('troubleshooting', 80),
#  ('tableau', 80),
#  ('month', 80),
#  ('apps', 80),
#  ('puppet', 79),
#  ('custom', 78),
#  ('asset', 78),
#  ('effectiveness', 78),
#  ('provider', 78),
#  ('sense', 77),
#  ('operation', 77),
#  ('space', 77),
#  ('http', 77),
#  ('perl', 77),
#  ('assist', 77),
#  ('revenue', 77),
#  ('hoc', 76),
#  ('online', 76),
#  ('discipline', 76),
#  ('approach', 76),
#  ('college', 76),
#  ('collaborate', 75),
#  ('making', 75),
#  ('money', 75),
#  ('splunk', 75),
#  ('mobile', 74),
#  ('virtualization', 74),
#  ('california', 74),
#  ('file', 74),
#  ('hbase', 74),
#  ('conduct', 74),
#  ('supervision', 74),
#  ('number', 73),
#  ('sr.', 73),
#  ('salary', 73),
#  ('depth', 73),
#  ('case', 73),
#  ('commerce', 72),
#  ('schedule', 72),
#  ('combination', 72),
#  ('stock', 72),
#  ('feedback', 71),
#  ('workforce', 71),
#  ('rate', 71),
#  ('json', 71),
#  (u'schema', 71),
#  ('root', 71),
#  ('proficient', 71),
#  ('chain', 70),
#  ('drug', 70),
#  ('ee', 70),
#  ('coverage', 70),
#  ('mining', 70),
#  ('inventory', 70),
#  ('v', 70),
#  ('analyze', 70),
#  ('start', 69),
#  ('commitment', 69),
#  ('mvc', 69),
#  ('db', 69),
#  ('post', 69),
#  ('aspera', 69),
#  ('acceptance', 68),
#  ('interaction', 68),
#  ('driven', 68),
#  ('administrator', 68),
#  ('vacation', 67),
#  ('device', 67),
#  ('type', 67),
#  ('setup', 67),
#  ('definition', 67),
#  ('scrum', 66),
#  ('f', 66),
#  ('supply', 66),
#  ('chef', 65),
#  ('kafka', 65),
#  ('game', 65),
#  ('conversion', 65),
#  ('powerpoint', 64),
#  ('check', 64),
#  ('tech', 63),
#  ('crm', 63),
#  ('perform', 63),
#  ('designer', 63),
#  ('google', 63),
#  ('vmware', 63),
#  ('list', 63),
#  ('investigation', 62),
#  ('traffic', 62),
#  ('php', 62),
#  ('distribution', 62),
#  ('middleware', 62),
#  ('home', 62),
#  ('evaluation', 62),
#  ('microstrategy', 62),
#  ('oversight', 61),
#  ('input', 61),
#  ('verbal', 61),
#  ('hire', 61),
#  ('jira', 61),
#  ('telephone', 61),
#  ('art', 61),
#  ('accuracy', 60),
#  ('issue', 60),
#  ('specialist', 59),
#  ('willingness', 59),
#  ('manufacturing', 59),
#  ('box', 59),
#  ('ramon', 59),
#  ('docker', 59),
#  ('operating', 59),
#  ('detection', 59),
#  ('accommodation', 59),
#  ('emphasis', 59),
#  ('layer', 59),
#  ('adoption', 59),
#  ('transfer', 59),
#  ('tier', 58),
#  ('event', 58),
#  ('initiative', 58),
#  ('flexibility', 58),
#  ('query', 58),
#  ('view', 58),
#  ('series', 57),
#  ('set', 57),
#  ('contribute', 57),
#  ('chance', 57),
#  ('half', 57),
#  ('history', 57),
#  ('starter', 57),
#  ('cause', 57),
#  ('room', 57),
#  ('place', 57),
#  ('feature', 56),
#  ('diversity', 56),
#  ('authentication', 56),
#  ('regression', 56),
#  ('tcp', 56),
#  ('incident', 55),
#  ('iot', 55),
#  ('drive', 55),
#  ('identifying', 55),
#  ('officer', 55),
#  ('version', 55),
#  ('warehousing', 55),
#  ('app', 55),
#  ('designing', 54),
#  ('foundation', 54),
#  ('concept', 54),
#  ('configure', 54),
#  ('stability', 54),
#  ('saas', 54),
#  ('selection', 54),
#  ('amazon', 54),
#  ('relocation', 54),
#  ('informatica', 54),
#  ('disaster', 53),
#  ('supervisor', 53),
#  ('accordance', 53),
#  ('equivalent', 53),
#  ('ssis', 53),
#  ('tuning', 53),
#  ('energy', 53),
#  ('ecosystem', 53),
#  ('participate', 52),
#  ('troubleshoot', 52),
#  ('develop', 52),
#  ('duration', 52),
#  ('teamwork', 52),
#  ('bsa', 52),
#  ('engine', 52),
#  ('engagement', 51),
#  ('intrusion', 51),
#  ('stage', 51),
#  ('entertainment', 51),
#  ('effort', 51),
#  ('week', 51),
#  ('script', 51),
#  ('ba', 50),
#  ('influence', 50),
#  ('study', 50),
#  ('l', 50),
#  ('apache', 50),
#  ('productivity', 50),
#  ('deploy', 50),
#  ('satisfaction', 50),
#  ('directory', 49),
#  ('adhering', 49),
#  ('course', 49),
#  ('expansion', 49),
#  ('campaign', 49),
#  ('flow', 49),
#  ('demand', 49),
#  ('pipeline', 49),
#  ('prioritization', 48),
#  ('meeting', 48),
#  ('studio', 48),
#  ('macys.com', 48),
#  ('pressure', 47),
#  ('website', 47),
#  ('coordinate', 47),
#  ('vulnerability', 47),
#  ('wealth', 47),
#  ('visio', 47),
#  ('fun', 47),
#  ('profile', 47),
#  ('advantage', 47),
#  ('managing', 47),
#  ('identification', 47),
#  ('mapping', 46),
#  ('log', 46),
#  ('transition', 46),
#  ('capability', 46),
#  ('entry', 46),
#  ('progress', 46),
#  ('proposal', 46),
#  ('sdlc', 46),
#  ('genesis', 45),
#  ('acquisition', 45),
#  ('payment', 45),
#  ('priority', 45),
#  ('adobe', 45),
#  ('bayonesolutions.com', 45),
#  ('store', 45),
#  (u'sa', 44),
#  ('inclusion', 44),
#  ('secure', 44),
#  ('landscape', 44),
#  ('postgresql', 44),
#  ('component', 44),
#  ('connect', 44),
#  ('fax', 44),
#  ('implementing', 44),
#  ('pto', 44),
#  ('pl', 44),
#  ('usage', 44),
#  ('legacy', 43),
#  ('format', 43),
#  ('desk', 43),
#  ('backup', 43),
#  ('dot', 43),
#  ('bay', 43),
#  ('pay', 43),
#  ('communicate', 43),
#  ('react', 43),
#  ('.net', 43),
#  ('sfdc', 43),
#  ('verizon', 43),
#  ('investment', 42),
#  ('owner', 42),
#  ('android', 42),
#  ('scripting', 42),
#  ('visibility', 42),
#  ('voip', 42),
#  ('force', 42),
#  ('park', 42),
#  ('prevention', 42),
#  ('staffing', 42),
#  ('top', 42),
#  ('pleasanton', 42),
#  ('discovery', 42),
#  ('salesforce.com', 42),
#  ('backbone', 42),
#  ('w', 41),
#  ('h', 41),
#  ('overview', 41),
#  ('speed', 41),
#  ('gathering', 41),
#  ('rdbms', 41),
#  ('estate', 41),
#  ('llp', 41),
#  (u'pm', 41),
#  ('junit', 41),
#  ('proof', 41),
#  ('note', 40),
#  ('award', 40),
#  ('ground', 40),
#  ('mentoring', 40),
#  ('summary', 40),
#  ('careers.deloitte.com', 40),
#  ('redwood', 40),
#  ('micro', 40),
#  ('funding', 40),
#  ('recognition', 40),
#  ('exchange', 40),
#  ('corp', 40),
#  ('soa', 39),
#  ('image', 39),
#  ('diverse', 39),
#  ('government', 39),
#  ('participation', 39),
#  ('family', 39),
#  ('ecommerce', 39),
#  ('macy', 39),
#  ('facing', 39),
#  ('passionate', 39),
#  ('request', 39),
#  ('pig', 39),
#  ('batch', 39),
#  ('coordinator', 39),
#  ('visa', 38),
#  ('transport', 38),
#  ('sharepoint', 38),
#  ('protocol', 38),
#  ('collection', 38),
#  ('specification', 38),
#  ('mdm', 37),
#  ('command', 37),
#  ('cybersecurity', 37),
#  ('mapreduce', 37),
#  ('remediation', 37),
#  ('twitter', 37),
#  ('tomcat', 37),
#  ('id', 37),
#  ('identify', 37),
#  ('erp', 37),
#  ('patriot', 37),
#  ('creativity', 37),
#  ('cyber', 37),
#  ('b.s', 37),
#  ('tax', 37),
#  ('execute', 37),
#  ('extraction', 36),
#  ('hibernate', 36),
#  ('attitude', 36),
#  ('+', 36),
#  ('partnership', 36),
#  ('safety', 36),
#  ('mongodb', 36),
#  ('alignment', 36),
#  ('mateo', 36),
#  ('behavior', 36),
#  ('knowing', 36),
#  ('logic', 35),
#  ('centurylink', 35),
#  ('competency', 35),
#  ('css3', 35),
#  ('bash', 35),
#  ('transaction', 35),
#  ('u.s.', 35),
#  ('map', 35),
#  ('awareness', 35),
#  ('house', 35),
#  ('purpose', 35),
#  ('skillsability', 35),
#  ('memory', 35),
#  ('context', 35),
#  ('conversation', 35),
#  ('opening', 35),
#  ('branch', 35),
#  ('assignment', 34),
#  ('customization', 34),
#  ('choice', 34),
#  ('com', 34),
#  ('coherent', 34),
#  ('size', 34),
#  ('browser', 34),
#  ('liaison', 34),
#  ('git', 34),
#  ('name', 34),
#  ('redis', 34),
#  ('escalation', 34),
#  ('engineerlocation', 34),
#  ('insight', 33),
#  ('receiving', 33),
#  ('metadata', 33),
#  ('facilitation', 33),
#  ('aptitude', 33),
#  ('math', 33),
#  ('procurement', 33),
#  ('writing', 33),
#  ('style', 33),
#  ('django', 32),
#  ('play', 32),
#  ('rotation', 32),
#  ('skillsexperience', 32),
#  (u'america', 32),
#  ('selenium', 32),
#  ('motivation', 32),
#  ('marketplace', 32),
#  ('balance', 32),
#  ('coaching', 32),
#  ('bug', 32),
#  ('usability', 32),
#  ('ot', 32),
#  ('ledger', 32),
#  ('category', 32),
#  ('letter', 31),
#  ('billing', 31),
#  ('offer', 31),
#  ('working', 31),
#  ('sponsorship', 31),
#  ('challenge', 31),
#  ('co', 31),
#  ('angularjs', 31),
#  ('negotiation', 31),
#  ('stakeholder', 31),
#  (u'ii', 31),
#  ('transportation', 31),
#  ('lan', 31),
#  ('firewall', 31),
#  ('audience', 31),
#  ('workflow', 31),
#  ('scheduling', 31),
#  ('complexity', 31),
#  ('everything', 31),
#  ('storm', 31),
#  ('menlo', 30),
#  ('nature', 30),
#  ('sf', 30),
#  ('hcm', 30),
#  ('confluence', 30),
#  ('malware', 30),
#  ('dba', 30),
#  ('packet', 30),
#  ('protection', 30),
#  ('target', 30),
#  ('ibm', 30),
#  ('x', 30),
#  ('recruiter', 30),
#  ('potential', 30),
#  ('speech', 30),
#  ('pre', 30),
#  ('debug', 29),
#  ('difference', 29),
#  ('tracking', 29),
#  ('contributor', 29),
#  ('asp.net', 29),
#  ('admin', 29),
#  ('replication', 29),
#  ('wan', 29),
#  ('soc', 29),
#  ('outlook', 29),
#  ('hi', 29),
#  ('reference', 29),
#  ('initio', 29),
#  ('shift', 29),
#  ('elasticsearch', 29),
#  ('citizenship', 29),
#  ('define', 29),
#  ('excellent', 29),
#  ('wireless', 29),
#  ('plusexperience', 29),
#  ('g', 29),
#  ('laboratory', 28),
#  ('sme', 28),
#  ('apply', 28),
#  (u'cm', 28),
#  ('phd', 28),
#  ('hand', 28),
#  ('professionalism', 28),
#  ('trial', 28),
#  ('accountability', 28),
#  ('paas', 28),
#  ('accurate', 28),
#  ('rht.com', 28),
#  ('debugging', 28),
#  ('ambiguity', 28),
#  ('coding', 28),
#  ('trust', 28),
#  ('district', 28),
#  ('advocate', 28),
#  ('clarity', 27),
#  ('dental', 27),
#  ('preference', 27),
#  ('lab', 27),
#  ('latency', 27),
#  ('board', 27),
#  ('authorization', 27),
#  ('robert', 27),
#  ('consistency', 27),
#  ('approval', 27),
#  ('well', 27),
#  ('entity', 27),
#  ('encryption', 27),
#  ('cluster', 27),
#  ('advice', 27),
#  ('gap', 27),
#  ('vpn', 27),
#  ('stream', 27),
#  ('sox', 27),
#  ('pc', 27),
#  ('contractor', 27),
#  ('apple', 27),
#  ('readiness', 27),
#  ('agency', 27),
#  ('classification', 26),
#  ('concord', 26),
#  ('facility', 26),
#  ('sign', 26),
#  ('trade', 26),
#  ('ci', 26),
#  ('learner', 26),
#  ('cell', 26),
#  ('globe', 26),
#  ('activation', 26),
#  ('grade', 26),
#  ('preparation', 26),
#  ('movement', 26),
#  ('hearing', 26),
#  ('fashion', 26),
#  ('medium', 26),
#  ('cash', 26),
#  ('statement', 26),
#  ('ethnicity', 26),
#  ('percent', 26),
#  ('maintaining', 25),
#  ('tm', 25),
#  ('biology', 25),
#  ('offering', 25),
#  ('inc', 25),
#  ('hp', 25),
#  ('eye', 25),
#  ('material', 25),
#  ('fault', 25),
#  ('valley', 25),
#  ('ssrs', 25),
#  ('jms', 24),
#  ('respond', 24),
#  ('union', 24),
#  ('mitigation', 24),
#  ('xml', 24),
#  ('powercenter', 24),
#  ('golf', 24),
#  ('repair', 24),
#  ('urgency', 24),
#  ('message', 24),
#  ('validate', 24),
#  ('treatment', 24),
#  ('redshift', 24),
#  ('evaluate', 24),
#  ('aws', 24),
#  ('capture', 24),
#  ('enhance', 24),
#  ('posting', 24),
#  ('visit', 24),
#  ('ajax', 24),
#  ('forecasting', 24),
#  ('connectivity', 24),
#  ('sector', 24),
#  ('sdk', 24),
#  ('campus', 24),
#  ('path', 24),
#  ('outcome', 24),
#  (u'ssa', 24),
#  ('cognizant', 24),
#  ('notch', 24),
#  ('triage', 24),
#  ('solver', 23),
#  ('validity', 23),
#  ('persistence', 23),
#  ('cd', 23),
#  ('vp', 23),
#  ('advertising', 23),
#  ('utilization', 23),
#  ('confidentiality', 23),
#  ('loss', 23),
#  ('retention', 23),
#  ('experienceexperience', 23),
#  ('node.js', 23),
#  ('tdd', 23),
#  ('communicator', 23),
#  ('qualification', 23),
#  ('school', 23),
#  ('picture', 23),
#  ('ssl', 23),
#  ('period', 23),
#  ('license', 23),
#  ('mpls', 23),
#  ('dns', 22),
#  ('pregnancy', 22),
#  ('youwe', 22),
#  ('nosql', 22),
#  ('ab', 22),
#  ('adherence', 22),
#  ('rollout', 22),
#  ('face', 22),
#  (u'posse', 22),
#  ('provide', 22),
#  ('trouble', 22),
#  ('card', 22),
#  ('ceo', 22),
#  ('bigdata', 22),
#  ('specialty', 22),
#  ('front', 22),
#  ('ancestry', 22),
#  ('route', 22),
#  ('page', 22),
#  ('itil', 22),
#  ('provisioning', 22),
#  ('configuring', 22),
#  ('train', 22),
#  ('recommendation', 22),
#  ('host', 22),
#  ('computing', 22),
#  ('footprint', 22),
#  ('story', 22),
#  ('york', 22),
#  ('boot', 22)]
